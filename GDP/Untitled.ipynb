# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('GDP.csv', encoding='iso8859_11')

# %%
df= df.drop(labels='Unnamed: 1',axis=1)

# %%
df = df.drop([0,1],axis=0)

# %%
df = df.drop([3,4],axis=0)

# %%
df = df.drop([88,:],axis=0)
# Out:
#   File "<ipython-input-15-d2ccc84c92ed>", line 1
#     df = df.drop([88,:],axis=0)
#                      ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#     รายได้เฉลี่ยต่อเดือนต่อครัวเรือน จำแนกตามภาค และจังหวัด พ.ศ. 2541 - 2558  \
# 2                                       ภาค และจังหวัด
# 5                                     ทั่วราชอาณาจักร
# 6                                            ตอนพิเศษ
# 7                                       กรุงเทพมหานคร
# 8                                         สมุทรปราการ
# 9                                             นนทบุรี
# 10                                           ปทุมธานี
# 11                                            ภาคกลาง
# 12                                    พระนครศรีอยุธยา
# 13                                            อ่างทอง
# 14                                             ลพบุรี
# 15                                          สิงห์บุรี
# 16                                             ชัยนาท
# 17                                            สระบุรี
# 18                                             ชลบุรี
# 19                                              ระยอง
# ...
