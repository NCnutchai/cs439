# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('monk.xls',sheet_name='2-จำนวนพระ')

# %%
df
# Out:
#    จำนวนพระภิกษุ - สามเณร ประจำปี 2557 (แยกรายจังหวัด)     Unnamed: 1  \
# 0                                                 ที่         จังหวัด
# 1                                                 NaN             NaN
# 2                                                   1   กรุงเทพมหานคร
# 3                                                   2          กระบี่
# 4                                                   3       กาญจนบุรี
# 5                                                   4       กาฬสินธุ์
# 6                                                   5       กำแพงเพชร
# 7                                                   6         ขอนแก่น
# 8                                                   7        จันทบุรี
# 9                                                   8      ฉะเชิงเทรา
# 10                                                  9          ชลบุรี
# 11                                                 10          ชัยนาท
# ...

# %%
# Out:
# 0
